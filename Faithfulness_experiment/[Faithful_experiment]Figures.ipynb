# %% [markdown]
# ### Plot weight decay vs faithfulness experiment

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
attattribute_weight_decay = np.array([[0.8407, 0.8448, 0.8271, 0.8238, 0.8419, 0.8085], 
                        [0.7227, 0.7289, 0.6916, 0.7052, 0.6808, 0.6889],
                        [0.7672, 0.7725, 0.7385, 0.7510, 0.7309, 0.7354],
                        [0.7076, 0.6822, 0.6818, 0.6741, 0.7363, 0.7002],
                        [0.7788, 0.8108, 0.8114, 0.7955, 0.7688, 0.6976],
                        [0.8322, 0.8614, 0.8607, 0.8442, 0.8243, 0.7548],
                        [0.9667, 0.9709, 0.9569, 0.9850, 0.9800, 0.9678]])
attattribute_sim_weight_decay = np.array([[0.7648, 0.7646, 0.7498, 0.7493, 0.7637, 0.7396],
                            [0.7120, 0.7156, 0.6798, 0.6932, 0.6690, 0.6825],
                            [0.7637, 0.7661, 0.7333, 0.7461, 0.7252, 0.7338],
                            [0.6536, 0.6263, 0.6275, 0.6197, 0.6837, 0.6577],
                            [0.7667, 0.7970, 0.8003, 0.7834, 0.7577, 0.6954],
                            [0.8290, 0.8564, 0.8583, 0.8408, 0.8189, 0.7554],
                            [0.9681, 0.9740, 0.9597, 0.9807, 0.9793, 0.9647]])

# %%
# Draw line plots for the experiment results

plt.figure(figsize=(8, 8), dpi=120)
plt.plot(range(1, 7), attattribute_weight_decay.mean(axis=0), label='Attribute', marker='o', color='#f24141', linewidth=2, markersize=10)
plt.plot(range(1, 7), attattribute_sim_weight_decay.mean(axis=0), label='Attribute_sim', marker='o', color='#f2b707', linewidth=2, markersize=10)   
# plt.plot([0, 0.0001, 0.0005, 0.001, 0.005, 0.01], avgatt.mean(axis=0), label='Avg_att', marker='o', color='green', linewidth=2, markersize=10)

plt.xticks(range(1, 7), ['0', '0.0001', '0.0005', '0.001', '0.005', '0.01'], fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Weight decay', fontsize=20)
plt.ylabel('Average performance', fontsize=20)
plt.title('Weight decay (Averaged performance)', fontsize=15)
plt.legend(fontsize=20)
plt.show()

# %%
# Draw line plots for the experiment results
# Now, draw all rows of the table for attattribute_weight_decay and attattribute_sim_weight_decay (keep the color)
plt.figure(figsize=(7, 7), dpi=120)
plt.plot(range(1, 7), attattribute_weight_decay[0], label='Pearson\'s rho', color='#F24141', marker='o')
plt.plot(range(1, 7), attattribute_weight_decay[1], label='Kendall\'s tau', color='#DB4930', marker='o')
plt.plot(range(1, 7), attattribute_weight_decay[2], label='Spearman\'s rho', color='#F97037', marker='o')
plt.plot(range(1, 7), attattribute_sim_weight_decay[0], label='Pearson\'s rho', color='#3BBCD9', marker='o')
plt.plot(range(1, 7), attattribute_sim_weight_decay[1], label='Kendall\'s tau', color='#359CF0', marker='o')
plt.plot(range(1, 7), attattribute_sim_weight_decay[2], label='Spearman\'s rho', color='#3266E6', marker='o')


plt.xticks(range(1, 7), ['0', '0.0001', '0.0005', '0.001', '0.005', '0.01'], fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Weight decay', fontsize=20)
plt.ylabel('Average performance', fontsize=20)
plt.title('Weight decay (ΔPC)', fontsize=20)
plt.legend(fontsize=15, loc='upper right')
plt.show()

# %%
attattribute = np.array([[0.8485, 0.8536, 0.8645, 0.8577, 0.8485], 
                        [0.7351, 0.7329, 0.7266, 0.7286, 0.7351],
                        [0.7815, 0.7807, 0.7741, 0.7753, 0.7815],
                        [0.7395, 0.7314, 0.7879, 0.7458, 0.7395],
                        [0.8022, 0.7791, 0.7950, 0.8109, 0.8022],
                        [0.8527, 0.8339, 0.8484, 0.8590, 0.8527],
                        [0.9737, 0.9528, 0.9668, 0.9571, 0.9737]])
attattribute_sim = np.array([[0.7704, 0.7747, 0.7889, 0.7852, 0.7704],
                            [0.7252, 0.7221, 0.7128, 0.7147, 0.7252],
                            [0.7785, 0.7766, 0.7671, 0.7673, 0.7785],
                            [0.6827, 0.6721, 0.7336, 0.6953, 0.6827],
                            [0.7921, 0.7663, 0.7809, 0.7970, 0.7921],
                            [0.8509, 0.8299, 0.8429, 0.8526, 0.8509],
                            [0.9719, 0.9447, 0.9691, 0.9555, 0.9719]])

# %%
# Draw line plots for the experiment results

plt.figure(figsize=(10, 10), dpi=120)
plt.plot(range(1, 6), attattribute.mean(axis=0), label='Attribute', marker='o', color='#f24141', linewidth=2, markersize=10)
plt.plot(range(1, 6), attattribute_sim.mean(axis=0), label='Attribute_sim', marker='o', color='#f2b707', linewidth=2, markersize=10)   
# plt.plot([0, 0.0001, 0.0005, 0.001, 0.005, 0.01], avgatt.mean(axis=0), label='Avg_att', marker='o', color='green', linewidth=2, markersize=10)

plt.xticks(range(1, 6), ['0', '0.2', '0.4', '0.6', '0.8'], fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Dropout', fontsize=20)
plt.ylabel('Average performance', fontsize=20)
plt.title('Dropout (Averaged performance)', fontsize=15)
plt.legend(fontsize=15, loc='lower right')
plt.show()
